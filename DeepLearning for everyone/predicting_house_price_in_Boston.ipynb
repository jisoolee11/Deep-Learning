# %% [markdown]
# <a href="https://colab.research.google.com/github/jisoolee11/Deep-Learning/blob/main/DeepLearning%20for%20everyone/predicting_house_price_in_Boston.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h1>보스턴 집값 예측하기

# %%
from keras.models import Sequential
from keras.layers import Dense
from sklearn.model_selection import train_test_split

import numpy
import pandas as pd
import tensorflow as tf

# %%
# seed 값 설정
# seed = 0
# numpy.random.seed(seed)
# tf.random.set_seed(3)

df = pd.read_csv('housing.csv', delim_whitespace=True, header=None)
dataset = df.values
X = dataset[:, 0:13]
Y = dataset[:, 13]
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3)  #, random_state=seed

model = Sequential()
model.add(Dense(30, input_dim=13, activation='relu'))
model.add(Dense(6, activation='relu'))
model.add(Dense(1))

model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(X_train, Y_train, epochs=200, batch_size=10)
# Out:
# Epoch 1/200
# 36/36 [==============================] - 0s 1ms/step - loss: 2864.5011
# Epoch 2/200
# 36/36 [==============================] - 0s 1ms/step - loss: 321.1908
# Epoch 3/200
# 36/36 [==============================] - 0s 994us/step - loss: 195.6877
# Epoch 4/200
# 36/36 [==============================] - 0s 1ms/step - loss: 155.5935
# Epoch 5/200
# 36/36 [==============================] - 0s 1ms/step - loss: 106.9753
# Epoch 6/200
# 36/36 [==============================] - 0s 2ms/step - loss: 120.8951
# Epoch 7/200
# 36/36 [==============================] - 0s 1ms/step - loss: 78.5137
# Epoch 8/200
# 36/36 [==============================] - 0s 1ms/step - loss: 83.4389
# Epoch 9/200
# 36/36 [==============================] - 0s 1ms/step - loss: 85.7028
# Epoch 10/200
# 36/36 [==============================] - 0s 1ms/step - loss: 55.9386
# Epoch 11/200
# 36/36 [==============================] - 0s 1ms/step - loss: 66.7182
# Epoch 12/200
# ...

# %%
# 예측 값과 실제 값의 비교
Y_prediction = model.predict(X_test).flatten()
for i in range(1,20):
  label = Y_test[i]
  prediction =Y_prediction[i]
  print("실제가격: {:.3f}, 예상가격: {:.3f}".format(label,prediction))
# Out:
# 실제가격: 50.000, 예상가격: 25.234
# 실제가격: 23.000, 예상가격: 27.837
# 실제가격: 8.300, 예상가격: 15.557
# 실제가격: 21.200, 예상가격: 22.732
# 실제가격: 19.900, 예상가격: 22.981
# 실제가격: 20.600, 예상가격: 22.903
# 실제가격: 18.700, 예상가격: 24.656
# 실제가격: 16.100, 예상가격: 20.703
# 실제가격: 18.600, 예상가격: 11.654
# 실제가격: 8.800, 예상가격: 14.429
# 실제가격: 17.200, 예상가격: 16.951
# 실제가격: 14.900, 예상가격: 19.990
# 실제가격: 10.500, 예상가격: 10.437
# 실제가격: 50.000, 예상가격: 42.223
# 실제가격: 29.000, 예상가격: 31.038
# 실제가격: 23.000, 예상가격: 23.547
# 실제가격: 33.300, 예상가격: 31.193
# 실제가격: 29.400, 예상가격: 31.460
# 실제가격: 21.000, 예상가격: 22.956
